# %%
import matplotlib.pyplot as plt
import numpy as np 
from math import sqrt 
from math import floor
from math import ceil
from math import exp 
import pickle
from operator import itemgetter
import time
from datetime import timedelta
import matplotlib
from matplotlib import cm, colors
from numpy import amin, amax, ravel
from scipy.optimize import curve_fit

import pandas as pd

# %%
fig = plt.figure(figsize=(13, 10))
ax = fig.add_subplot(111)

data = pd.read_csv("/home/kamilla/ABP/Lab_2/cublas_task1.txt", sep='\s+', header=None)
plt.loglog(data[4], data[15], "s",label ="cublas, M*N")

data = pd.read_csv("/home/kamilla/ABP/Lab_2/my_task1.txt", sep='\s+', header=None)
plt.loglog(data[4], data[15], "s",label ="CUDA-implementation, M*N")
 

plt.title("Memory bandwidth:  memory operations per second", fontsize=24)
plt.ylabel("GB/s", fontsize=20)

plt.tick_params(axis='x', labelsize=20) 
plt.tick_params(axis='y', labelsize=20) 

plt.legend(fontsize=15)

plt.savefig("uppmax_memory.png", bbox_inches='tight')

# %%
fig = plt.figure(figsize=(13, 10))
ax = fig.add_subplot(111)

data = pd.read_csv("/home/kamilla/ABP/Lab_2/task1_1024_cublas.log", sep='\s+', header=None)
plt.loglog(data[4], data[15], "s",label ="cublas")

data = pd.read_csv("/home/kamilla/ABP/Lab_2/task1_1024.log", sep='\s+', header=None)
plt.loglog(data[4], data[15], "s",label ="CUDA-implementation, blocksize=1024")
 
data = pd.read_csv("/home/kamilla/ABP/Lab_2/task1_512.log", sep='\s+', header=None)
plt.loglog(data[4], data[15], "s",label ="CUDA-implementation, blocksize=512")

plt.title("Memory bandwidth:  memory operations per second", fontsize=24)
plt.ylabel("GB/s", fontsize=20)

plt.tick_params(axis='x', labelsize=20) 
plt.tick_params(axis='y', labelsize=20) 

plt.legend(fontsize=15)

plt.savefig("task1a.png", bbox_inches='tight')

# %%
fig = plt.figure(figsize=(13, 10))
ax = fig.add_subplot(111)

data = pd.read_csv("/home/kamilla/ABP/Lab_2/task1b_1024_cublas.log", sep='\s+', header=None)
plt.loglog(data[4], data[15], "s",label ="cublas, fixed column")
x=data[4]


data = pd.read_csv("/home/kamilla/ABP/Lab_2/taskb_1024.log", sep='\s+', header=None)
plt.loglog(x[::2], data[15][1:], "s",label ="CUDA, blocksize=1024, fixed column")
 
 
data = pd.read_csv("/home/kamilla/ABP/Lab_2/task1c_16384_1024_cublas.log", sep='\s+', header=None)
plt.loglog(x, data[15], "s",label ="cublas, fixed row")
#x=data[4]


#data = pd.read_csv("/home/kamilla/ABP/Lab_2/taskc_16384_1024.log", sep='\s+', header=None)
#plt.loglog(x[::2], data[15], "s",label ="CUDA, blocksize=1024, fixed row")
data = pd.read_csv("/home/kamilla/ABP/Lab_2/task1_1024.log", sep='\s+', header=None)
plt.loglog(data[4], data[15], "s",label ="CUDA, blocksize=1024, square")

data = pd.read_csv("/home/kamilla/ABP/Lab_2/taskc_16384_1024.log", sep='\s+', header=None)
plt.loglog(data[4], data[15], "s",label ="CUDA,  fixed rows")

plt.title("Memory bandwidth:  memory operations per second", fontsize=24)
plt.ylabel("GB/s", fontsize=20)

plt.tick_params(axis='x', labelsize=20) 
plt.tick_params(axis='y', labelsize=20) 

plt.legend(fontsize=15)

plt.savefig("task1b.png", bbox_inches='tight')

# %%
fig = plt.figure(figsize=(13, 10))
ax = fig.add_subplot(111)

data = pd.read_csv("/home/kamilla/ABP/Lab_2/task_matrix_cublas.log", sep='\s+', header=None)
plt.loglog(data[4], data[12]*data[4]*data[4]*3, "s",label ="cublas ")

data = pd.read_csv("/home/kamilla/ABP/Lab_2/matrixmatrix.log", sep='\s+', header=None)
plt.loglog(data[4], data[12]*data[4]*data[4]*3, "s",label ="CUDA-implementation ")
 

plt.title(" Floating point performance", fontsize=24)
plt.ylabel("GFlop/s.", fontsize=20)

plt.tick_params(axis='x', labelsize=20) 
plt.tick_params(axis='y', labelsize=20) 

plt.legend(fontsize=15)

plt.savefig("matrix.png", bbox_inches='tight')
