# %%
import matplotlib.pyplot as plt
import numpy as np 
from math import sqrt 
from math import floor
from math import ceil
from math import exp 
import pickle
from operator import itemgetter
import time
from datetime import timedelta
import matplotlib
from matplotlib import cm, colors
from numpy import amin, amax, ravel
from scipy.optimize import curve_fit

import pandas as pd

# %%
fig = plt.figure(figsize=(13, 10))
ax = fig.add_subplot(111)

data = pd.read_csv("double_cpu_4.log", sep='\s+', header=None,skiprows=4)
data=data[::1000]
plt.plot(data[1], data[5], "s",label ="Double, OpenMP, 4 Process")

data = pd.read_csv("double_cpu_16.log", sep='\s+', header=None,skiprows=4)
data=data[::1000]
plt.plot(data[1], data[5], "s",label ="Double, OpenMP, 16 Process")

#data = pd.read_csv("double_cuda.log", sep='\s+', header=None,skiprows=5)
#data=data[::1000]
data = pd.read_csv("double_cuda_left.log", sep='\s+', header=None,skiprows=5)
data=data[::40]
plt.plot(data[1], data[5], "*",label ="Double, Cuda")

data = pd.read_csv("float_cpu_4.log", sep='\s+', header=None,skiprows=4)
data=data[::1000]
plt.plot(data[1], data[5], "o",label ="Float, OpenMP, 4 Process")

data = pd.read_csv("float_cpu_16.log", sep='\s+', header=None,skiprows=4)
data=data[::1000]
plt.plot(data[1], data[5], "o",label ="Float, OpenMP, 16 Process")

#data = pd.read_csv("float_cuda.log", sep='\s+', header=None,skiprows=5)
data = pd.read_csv("float_left_cuda.log", sep='\s+', header=None,skiprows=5)
data=data[::1000]
plt.plot(data[1], data[5], "*",label ="Float, Cuda")

plt.title("Memory bandwidth:  memory operations per second", fontsize=24)
plt.ylabel("GB/s", fontsize=20)

plt.tick_params(axis='x', labelsize=20) 
plt.tick_params(axis='y', labelsize=20) 

plt.legend(fontsize=15)
plt.tight_layout()
plt.semilogy()


plt.savefig("memory.png", bbox_inches='tight' )

# %%
fig = plt.figure(figsize=(13, 10))
ax = fig.add_subplot(111)

data = pd.read_csv("double_cpu_4.log", sep='\s+', header=None,skiprows=4)
data=data[::1000]
plt.plot(data[1], data[2], "s",label ="Double, OpenMP, 4 Process")

data = pd.read_csv("double_cpu_16.log", sep='\s+', header=None,skiprows=4)
data=data[::1000]
plt.plot(data[1], data[2], "s",label ="Double, OpenMP, 16 Process")

#data = pd.read_csv("double_cuda.log", sep='\s+', header=None,skiprows=5)
#data=data[::1000]
data = pd.read_csv("double_cuda_left.log", sep='\s+', header=None,skiprows=5)
data=data[::40]
plt.plot(data[1], data[2], "*",label ="Double, Cuda")

data = pd.read_csv("float_cpu_4.log", sep='\s+', header=None,skiprows=4)
data=data[::1000]
plt.plot(data[1], data[2], "o",label ="Float, OpenMP, 4 Process")

data = pd.read_csv("float_cpu_16.log", sep='\s+', header=None,skiprows=4)
data=data[::1000]
plt.plot(data[1], data[2], "o",label ="Float, OpenMP, 16 Process")

#data = pd.read_csv("float_cuda.log", sep='\s+', header=None,skiprows=5)
data = pd.read_csv("float_left_cuda.log", sep='\s+', header=None,skiprows=5)
data=data[::1000]
plt.plot(data[1], data[2], "*",label ="Float, Cuda")




plt.tick_params(axis='x', labelsize=20) 
plt.tick_params(axis='y', labelsize=20) 

plt.legend(fontsize=15)

plt.savefig("memory.png", bbox_inches='tight')


plt.legend(fontsize=15)


plt.semilogy()

plt.title("Computational performance", fontsize=24)
plt.ylabel("MUPD/s", fontsize=20)


plt.tick_params(axis='x', labelsize=20) 
plt.tick_params(axis='y', labelsize=20) 
plt.tight_layout()
plt.legend(fontsize=15)
plt.savefig("comp.png", bbox_inches='tight')

# %%
fig = plt.figure(figsize=(13, 10))
ax = fig.add_subplot(111)

data = pd.read_csv("float_cpu_4.log", sep='\s+', header=None,skiprows=4)
data=data[::1000]
#plt.plot(data[1], data[5], "s",label ="Right, OpenMP, 4 Process")

data = pd.read_csv("float_cuda.log", sep='\s+', header=None,skiprows=5)
data=data[::1000]
plt.plot(data[1], data[5], "*",label ="Right, Float, Cuda")



data = pd.read_csv("float_cpu_4_left.log", sep='\s+', header=None,skiprows=4)
data=data[::1000]
#plt.plot(data[1], data[5], "s",label ="Left, OpenMP, 4 Process")

data = pd.read_csv("float_left_cuda.log", sep='\s+', header=None,skiprows=5)
data=data[::1000]
plt.plot(data[1], data[5], "*",label ="Left, Float, Cuda")


plt.title("Memory bandwidth (float, CUDA):  LayoutLeft vs LayoutRight ", fontsize=24)
plt.ylabel("GB/s", fontsize=20)

plt.tick_params(axis='x', labelsize=20) 
plt.tick_params(axis='y', labelsize=20) 

plt.legend(fontsize=15)

plt.semilogy()
plt.tight_layout()
plt.savefig("memory_lr_cuda.png", bbox_inches='tight')

# %%
fig = plt.figure(figsize=(13, 10))
ax = fig.add_subplot(111)

data = pd.read_csv("float_cpu_4.log", sep='\s+', header=None,skiprows=4)
data=data[::1000]
plt.plot(data[1], data[5], "s",label ="Right, OpenMP, 4 Process")

data = pd.read_csv("float_cuda.log", sep='\s+', header=None,skiprows=5)
data=data[::1000]
#plt.plot(data[1], data[5], "*",label ="Right, Float, Cuda")



data = pd.read_csv("float_cpu_4_left.log", sep='\s+', header=None,skiprows=4)
data=data[::1000]
plt.plot(data[1], data[5], "s",label ="Left, OpenMP, 4 Process")

data = pd.read_csv("float_left_cuda.log", sep='\s+', header=None,skiprows=5)
data=data[::1000]
#plt.plot(data[1], data[5], "*",label ="Left, Float, Cuda")


plt.title("Memory bandwidth (float, OpenMP 4 process):  LayoutLeft vs LayoutRight ", fontsize=24)
plt.ylabel("GB/s", fontsize=20)

plt.tick_params(axis='x', labelsize=20) 
plt.tick_params(axis='y', labelsize=20) 

plt.legend(fontsize=15)

plt.savefig("memory_lr_openmp.png", bbox_inches='tight')

# %%
fig = plt.figure(figsize=(13, 10))
ax = fig.add_subplot(111)

data = pd.read_csv("float_cpu_16.log", sep='\s+', header=None,skiprows=4)
data=data[::1000]
plt.plot(data[1], data[5], "s",label ="Right, OpenMP, 16 Process")

data = pd.read_csv("float_cuda.log", sep='\s+', header=None,skiprows=5)
data=data[::1000]
#plt.plot(data[1], data[5], "*",label ="Right, Float, Cuda")



data = pd.read_csv("float_cpu_16_left.log", sep='\s+', header=None,skiprows=4)
data=data[::100]
plt.plot(data[1], data[5], "s",label ="Left, OpenMP, 16 Process")

data = pd.read_csv("float_left_cuda.log", sep='\s+', header=None,skiprows=5)
data=data[::1000]
#plt.plot(data[1], data[5], "*",label ="Left, Float, Cuda")


plt.title("Memory bandwidth (float, OpenMP 16 process):  LayoutLeft vs LayoutRight ", fontsize=24)
plt.ylabel("GB/s", fontsize=20)

plt.tick_params(axis='x', labelsize=20) 
plt.tick_params(axis='y', labelsize=20) 

plt.legend(fontsize=15)
plt.tight_layout()
plt.semilogy()
plt.savefig("memory_lr_openmp_16.png", bbox_inches='tight')

# %%
fig = plt.figure(figsize=(13, 10))
ax = fig.add_subplot(111)

data = pd.read_csv("time.log", sep='\s+', header=None,skiprows=5)
data=data[::10]
plt.loglog(data[4], data[0]+data[1], "s",label ="Transfer", alpha = 0.35)

plt.loglog(data[4], data[2]/20 , "s",label ="Calculations")
 
plt.loglog(data[4], data[2]/20+data[0]+data[1], "s",label ="Sum of time", alpha = 0.35 )
 

data = pd.read_csv("time_16.log", sep='\s+', header=None,skiprows=5)
data=data[::50]
plt.loglog(data[4], data[2]/20+data[0]+data[1] , "s",label ="CPU time")


plt.title("Time  ", fontsize=24)
plt.ylabel("s", fontsize=20)

plt.tick_params(axis='x', labelsize=20) 
plt.tick_params(axis='y', labelsize=20) 

plt.legend(fontsize=15)

plt.savefig("time.png", bbox_inches='tight')
